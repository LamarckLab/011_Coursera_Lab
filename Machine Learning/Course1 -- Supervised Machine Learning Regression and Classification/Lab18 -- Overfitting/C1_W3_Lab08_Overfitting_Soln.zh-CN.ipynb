# %% [markdown]
# <p align="right"><a href="./C1_W3_Lab08_Overfitting_Soln.ipynb">English</a> | <strong>中文</strong></p>

# %% [markdown]
# # Ungraded Lab: 过拟合（Overfitting）
#
# <img align="left" src="./images/C1_W3_Overfitting_a.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_b.png"     style=" width:250px; padding: 10px; " >
# <img align="left" src="./images/C1_W3_Overfitting_c.png"     style=" width:250px; padding: 10px; " >

# %% [markdown]
# ## 目标
# 在本实验中，你将探索：
# - 会发生过拟合（overfitting）的情形
# - 一些解决办法

# %%
# %matplotlib widget
import matplotlib.pyplot as plt
from ipywidgets import Output
from plt_overfit import overfit_example, output
plt.style.use('./deeplearning.mplstyle')

# %% [markdown]
# # 过拟合（Overfitting）
# 本周课程讲了可能出现过拟合的情形。运行下面的 cell 生成一张图，让你能探索过拟合。cell 下面还有进一步的说明。

# %%
plt.close("all")
display(output)
ofit = overfit_example(False)
# Out:
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 在上面的图里你可以：
# - 在 Regression（回归）和 Categorization（分类）两个例子之间切换
# - 添加数据
# - 选择模型的次数（degree）
# - 把模型拟合到数据上
#
# 下面是一些你应该试试的：
# - 用 degree = 1 拟合数据；注意 '欠拟合（underfitting）'。
# - 用 degree = 6 拟合数据；注意 '过拟合（overfitting）'
# - 调 degree 得到 '最佳拟合'
# - 添加数据：
#     - 极端样本（假设是离群点）会加重过拟合
#     - 普通样本可以减轻过拟合
# - 在 `Regression` 和 `Categorical` 之间切换，两个例子都试试。
#
# 要重置图，重新运行该 cell。慢点点击，让图更新完再点下一次。
#
# 实现方面的说明：
# - '理想（ideal）' 曲线代表加噪声前用来生成数据集的那个生成模型
# - 'fit' 为了提速没有用纯梯度下降。这些方法可用于较小的数据集。

# %% [markdown]
# ## 恭喜！
# 你已经对过拟合的成因和解决办法有了一些直觉。下一个实验里，你将探索一个常用的解决办法——正则化（Regularization）。
