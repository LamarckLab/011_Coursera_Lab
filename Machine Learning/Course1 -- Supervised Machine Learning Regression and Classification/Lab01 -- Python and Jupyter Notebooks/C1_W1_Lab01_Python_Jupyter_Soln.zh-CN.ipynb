# %% [markdown]
# <p align="right"><a href="./C1_W1_Lab01_Python_Jupyter_Soln.ipynb">English</a> | <strong>中文</strong></p>

# %% [markdown]
# # Optional Lab: Python 与 Jupyter Notebook 简介
# 欢迎来到第一个选修实验！
# 选修实验的作用：
# - 提供信息 —— 就像本 notebook
# - 用动手示例巩固课堂内容
# - 提供评分实验（graded labs）中所用函数的可运行示例

# %% [markdown]
# ## 目标
# 在本实验中，你将：
# - 简要了解 Jupyter notebook
# - 浏览 Jupyter notebook 的界面
# - 理解 markdown cell 与 code cell 的区别
# - 练习一些基础 Python

# %% [markdown]
# 熟悉 Jupyter notebook 最简单的方式，是使用上方 Help 菜单里的导览（tour）：

# %% [markdown]
# <figure>
#     <center> <img src="./images/C1W1L1_Tour.PNG"  alt='missing' width="400"  ><center/>
# <figure/>

# %% [markdown]
# 本课程用到两种 Jupyter notebook 的 cell。像这样包含说明文字的叫 `Markdown Cell`，名字来自 cell 中所用的这种简易排版语言。你不需要自己编写 markdown cell。了解下图所示的 `cell pulldown`（cell 类型下拉框）会很有用：偶尔某个 cell 会切换到错误的模式，这时你需要把它恢复到正确的状态：

# %% [markdown]
# <figure>
#    <img src="./images/C1W1L1_Markdown.PNG"  alt='missing' width="400"  >
# <figure/>

# %% [markdown]
# 另一种 cell 是 `code cell`，你将在其中编写代码：

# %%
#This is  a 'Code' Cell
print("Hello, Im code cell")
# Out:
# Hello, Im code cell

# %% [markdown]
# ## Python
# 你可以在 code cell 中编写代码。
# 运行代码时，选中该 cell，然后：
# - 按住 shift 键并敲 'enter' 或 'return'
# - 或点击上方的 'run' 运行箭头
# <figure>
#     <img src="./images/C1W1L1_Run.PNG"  width="400"  >
# <figure/>

# %% [markdown]
# ### print 语句
# print 语句通常采用 Python 的 f-string 写法。
# 在下面的 cell 中试着写一个你自己的 print。
# 两种运行 cell 的方式都试一试。

# %%
# print statements
variable = "right in the strings!"
print(f"f strings allow you to embed variables {variable}")
# Out:
# f strings allow you to embed variables right in the strings!

# %% [markdown]
# # 恭喜！
# 现在你已经能在 Jupyter Notebook 中操作自如了。
